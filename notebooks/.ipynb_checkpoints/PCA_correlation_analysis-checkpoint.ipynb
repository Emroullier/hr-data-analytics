# %% [markdown]
# # Import packages and modules

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Import data

# %%
# data = pd.read_csv("../DATA_HR")
data = os.getenv("DATA_HR")

# %%
data_df = pd.read_csv(data)

# %%
data_df.head()
# Out:
#    ID      Name       Department     GEO             Role  Rising_Star  \
# 0   1    BRADDY       Operations      US               VP          NaN
# 1   2     BORST            Sales      UK  Senior Director          NaN
# 2   3  BIRDWELL          Finance  France  Senior Director          NaN
# 3   4      BENT  Human Resources   China  Senior Director          NaN
# 4   5     BAZAN               IT   Korea         Director          NaN
#
#    Will_Relocate  Critical  Trending Perf  Talent_Level  ...  \
# 0              0       1.0              3             6  ...
# 1              0       NaN              3             6  ...
# 2              0       NaN              3             6  ...
# 3              0       NaN              3             6  ...
# 4              0       NaN              3             6  ...
#
#    Emp_Competitive_4  Emp_Competitive_5  Emp_Collaborative_1  \
# 0                  2                  2                    2
# 1                  4                  1                    3
# 2                  2                  5                    2
# 3                  5                  1                    1
# 4                  5                  3                    5
#
#    Emp_Collaborative_2  Emp_Collaborative_3  Emp_Collaborative_4  \
# 0                    2                    2                    1
# 1                    2                    5                    1
# 2                    2                    4                    4
# 3                    2                    4                    4
# 4                    1                    2                    5
#
#    Emp_Collaborative_5  Sensor_StepCount  Sensor_Heartbeat(Average/Min)  \
# 0                    5              1841                             61
# 1                    5              1990                             90
# 2                    4              3193                             80
# 3                    1              3248                             77
# 4                    4              3149                             80
#
#    Sensor_Proximity(1-highest/10-lowest)
# 0                                      9
# 1                                      8
# 2                                      8
# 3                                      6
# 4                                     10
#
# [5 rows x 62 columns]

# %% [markdown]
# # Clearing data

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 62 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     14999 non-null  int64
#  1   Name                                   14997 non-null  object
#  2   Department                             14999 non-null  object
#  3   GEO                                    14999 non-null  object
#  4   Role                                   14999 non-null  object
#  5   Rising_Star                            21 non-null     float64
#  6   Will_Relocate                          14999 non-null  int64
#  7   Critical                               480 non-null    float64
#  8   Trending Perf                          14999 non-null  int64
#  9   Talent_Level                           14999 non-null  int64
#  10  Validated_Talent_Level                 14999 non-null  int64
#  11  Percent_Remote                         14999 non-null  float64
#  12  EMP_Sat_OnPrem_1                       14871 non-null  float64
#  13  EMP_Sat_OnPrem_2                       14871 non-null  float64
#  14  EMP_Sat_OnPrem_3                       14871 non-null  float64
#  15  EMP_Sat_OnPrem_4                       14871 non-null  float64
#  16  EMP_Sat_OnPrem_5                       14871 non-null  float64
#  17  EMP_Sat_Remote_1                       14999 non-null  int64
#  18  EMP_Sat_Remote_2                       14999 non-null  int64
#  19  EMP_Sat_Remote_3                       14999 non-null  int64
#  20  EMP_Sat_Remote_4                       14999 non-null  int64
#  21  EMP_Sat_Remote_5                       14999 non-null  int64
#  22  EMP_Engagement_1                       14999 non-null  int64
#  23  EMP_Engagement_2                       14999 non-null  int64
#  24  EMP_Engagement_3                       14999 non-null  int64
#  25  EMP_Engagement_4                       14999 non-null  int64
#  26  EMP_Engagement_5                       14999 non-null  int64
#  27  last_evaluation                        14999 non-null  float64
#  28  number_project                         14999 non-null  int64
#  29  average_montly_hours                   14999 non-null  int64
#  30  time_spend_company                     14999 non-null  int64
#  31  Work_accident                          14999 non-null  int64
#  32  left_Company                           14999 non-null  int64
#  33  CSR Factor                             1713 non-null   float64
#  34  promotion_last_5years                  14999 non-null  int64
#  35  sales                                  14999 non-null  object
#  36  salary                                 14999 non-null  object
#  37  Gender                                 14999 non-null  object
#  38  LinkedIn_Hits                          14999 non-null  int64
#  39  Emp_Work_Status2                       14999 non-null  int64
#  40  Emp_Work_Status_3                      14999 non-null  int64
#  41  Emp_Work_Status_4                      14999 non-null  int64
#  42  Emp_Work_Status_5                      14999 non-null  int64
#  43  Emp_Identity                           14999 non-null  int64
#  44  Emp_Role                               14999 non-null  int64
#  45  Emp_Position                           14999 non-null  int64
#  46  Emp_Title                              14999 non-null  int64
#  47  Women_Leave                            7596 non-null   float64
#  48  Men_Leave                              4865 non-null   float64
#  49  Emp_Competitive_1                      14999 non-null  int64
#  50  Emp_Competitive_2                      14999 non-null  int64
#  51  Emp_Competitive_3                      14999 non-null  int64
#  52  Emp_Competitive_4                      14999 non-null  int64
#  53  Emp_Competitive_5                      14999 non-null  int64
#  54  Emp_Collaborative_1                    14999 non-null  int64
#  55  Emp_Collaborative_2                    14999 non-null  int64
#  56  Emp_Collaborative_3                    14999 non-null  int64
#  57  Emp_Collaborative_4                    14999 non-null  int64
#  58  Emp_Collaborative_5                    14999 non-null  int64
#  59  Sensor_StepCount                       14999 non-null  int64
#  60  Sensor_Heartbeat(Average/Min)          14999 non-null  int64
#  61  Sensor_Proximity(1-highest/10-lowest)  14999 non-null  int64
# dtypes: float64(12), int64(43), object(7)
# memory usage: 7.1+ MB

# %%
data_df.drop(columns=["ID", "Name", "Rising_Star", "Critical", "CSR Factor", "Talent_Level", "Validated_Talent_Level", "Trending Perf", "EMP_Sat_OnPrem_1", "EMP_Sat_OnPrem_2", "EMP_Sat_OnPrem_3", "EMP_Sat_OnPrem_4", "EMP_Sat_OnPrem_5"], inplace=True)

# %%
num_columns = data_df.select_dtypes(include=("int64", "float64")).columns

# %%
num_data = data_df[num_columns].copy()

# %% [markdown]
# # PCA analysis

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
pca = PCA()
min_max_scaler = MinMaxScaler()
s_scaler = StandardScaler()

# %%
# Filling Women_Leave and Men_Leave NaN with 0 (not left or not column gender)
num_data.fillna({"Women_Leave":0}, inplace=True)
num_data.fillna({"Men_Leave":0}, inplace=True)

# %%
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 43 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Will_Relocate                          14999 non-null  int64
#  1   Percent_Remote                         14999 non-null  float64
#  2   EMP_Sat_Remote_1                       14999 non-null  int64
#  3   EMP_Sat_Remote_2                       14999 non-null  int64
#  4   EMP_Sat_Remote_3                       14999 non-null  int64
#  5   EMP_Sat_Remote_4                       14999 non-null  int64
#  6   EMP_Sat_Remote_5                       14999 non-null  int64
#  7   EMP_Engagement_1                       14999 non-null  int64
#  8   EMP_Engagement_2                       14999 non-null  int64
#  9   EMP_Engagement_3                       14999 non-null  int64
#  10  EMP_Engagement_4                       14999 non-null  int64
#  11  EMP_Engagement_5                       14999 non-null  int64
#  12  last_evaluation                        14999 non-null  float64
#  13  number_project                         14999 non-null  int64
#  14  average_montly_hours                   14999 non-null  int64
#  15  time_spend_company                     14999 non-null  int64
#  16  Work_accident                          14999 non-null  int64
#  17  left_Company                           14999 non-null  int64
#  18  promotion_last_5years                  14999 non-null  int64
#  19  LinkedIn_Hits                          14999 non-null  int64
#  20  Emp_Work_Status2                       14999 non-null  int64
#  21  Emp_Work_Status_3                      14999 non-null  int64
#  22  Emp_Work_Status_4                      14999 non-null  int64
#  23  Emp_Work_Status_5                      14999 non-null  int64
#  24  Emp_Identity                           14999 non-null  int64
#  25  Emp_Role                               14999 non-null  int64
#  26  Emp_Position                           14999 non-null  int64
#  27  Emp_Title                              14999 non-null  int64
#  28  Women_Leave                            14999 non-null  float64
#  29  Men_Leave                              14999 non-null  float64
#  30  Emp_Competitive_1                      14999 non-null  int64
#  31  Emp_Competitive_2                      14999 non-null  int64
#  32  Emp_Competitive_3                      14999 non-null  int64
#  33  Emp_Competitive_4                      14999 non-null  int64
#  34  Emp_Competitive_5                      14999 non-null  int64
#  35  Emp_Collaborative_1                    14999 non-null  int64
#  36  Emp_Collaborative_2                    14999 non-null  int64
#  37  Emp_Collaborative_3                    14999 non-null  int64
#  38  Emp_Collaborative_4                    14999 non-null  int64
#  39  Emp_Collaborative_5                    14999 non-null  int64
#  40  Sensor_StepCount                       14999 non-null  int64
#  41  Sensor_Heartbeat(Average/Min)          14999 non-null  int64
#  42  Sensor_Proximity(1-highest/10-lowest)  14999 non-null  int64
# dtypes: float64(4), int64(39)
# memory usage: 4.9 MB

# %%
num_data_scaled = s_scaler.fit_transform(num_data)

# %%
pca.fit_transform(num_data_scaled)
# Out:
# array([[-3.10455819e+00,  3.51494318e+00, -5.88050251e-01, ...,
#         -1.27265840e-15, -1.56997464e-15, -1.22083468e-15],
#        [-3.11965103e+00,  3.11861632e+00,  1.24186653e+00, ...,
#         -1.70301549e-15, -1.73059221e-15, -4.54931933e-15],
#        [-2.89540857e+00,  3.05802589e+00,  8.49136188e-01, ...,
#         -9.12193759e-16, -1.98018415e-15, -3.49364169e-15],
#        ...,
#        [-1.35571791e-01, -6.56813626e+00,  1.47073291e+00, ...,
#         -7.44987348e-16, -1.61165503e-15, -5.01180762e-15],
#        [-8.40951624e-01, -6.33830143e+00,  1.42823810e+00, ...,
#         -2.98037644e-17, -1.63888413e-15, -4.71052137e-15],
#        [-4.49814023e-01, -5.66869297e+00, -4.56648836e-01, ...,
#         -1.50759528e-15, -2.02119045e-15, -6.26643342e-15]])

# %%
pca_feat_out = pca.get_feature_names_out()
pca_feat_in = num_data.columns

# %%
pca_corr = pd.DataFrame(pca.components_, columns=pca_feat_in, index=pca_feat_in)

# %%
# Defining a mask for visualization
mask = (pca_corr > .5) | (pca_corr < -.5)

def highlight_values(val):
    color = 'yellow' if val > .5 or val < -.5 else 'black'
    return f'background-color: {color}'

# %%
# Visualization w/ seaborn heatmap
import seaborn as sns

sns.heatmap(pca_corr, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# Visualization w/ numerical values
masked_pca_corr = pca_corr.where(mask)

# %%
pca_corr.style.apply(lambda x: x.map(highlight_values))
# Out:
# <style type="text/css">
# #T_b64ad_row0_col0, #T_b64ad_row0_col1, #T_b64ad_row0_col2, #T_b64ad_row0_col3, #T_b64ad_row0_col4, #T_b64ad_row0_col5, #T_b64ad_row0_col6, #T_b64ad_row0_col7, #T_b64ad_row0_col8, #T_b64ad_row0_col9, #T_b64ad_row0_col10, #T_b64ad_row0_col11, #T_b64ad_row0_col12, #T_b64ad_row0_col13, #T_b64ad_row0_col14, #T_b64ad_row0_col15, #T_b64ad_row0_col16, #T_b64ad_row0_col17, #T_b64ad_row0_col18, #T_b64ad_row0_col19, #T_b64ad_row0_col20, #T_b64ad_row0_col21, #T_b64ad_row0_col22, #T_b64ad_row0_col23, #T_b64ad_row0_col24, #T_b64ad_row0_col25, #T_b64ad_row0_col26, #T_b64ad_row0_col27, #T_b64ad_row0_col28, #T_b64ad_row0_col29, #T_b64ad_row0_col30, #T_b64ad_row0_col31, #T_b64ad_row0_col32, #T_b64ad_row0_col33, #T_b64ad_row0_col34, #T_b64ad_row0_col35, #T_b64ad_row0_col36, #T_b64ad_row0_col37, #T_b64ad_row0_col38, #T_b64ad_row0_col39, #T_b64ad_row0_col40, #T_b64ad_row0_col41, #T_b64ad_row0_col42, #T_b64ad_row1_col0, #T_b64ad_row1_col1, #T_b64ad_row1_col2, #T_b64ad_row1_col3, #T_b64ad_row1_col4, #T_b64ad_row1_col5, #T_b64ad_row1_col6, #T_b64ad_row1_col7, #T_b64ad_row1_col8, #T_b64ad_row1_col9, #T_b64ad_row1_col10, #T_b64ad_row1_col11, #T_b64ad_row1_col12, #T_b64ad_row1_col13, #T_b64ad_row1_col14, #T_b64ad_row1_col15, #T_b64ad_row1_col16, #T_b64ad_row1_col17, #T_b64ad_row1_col18, #T_b64ad_row1_col19, #T_b64ad_row1_col20, #T_b64ad_row1_col21, #T_b64ad_row1_col22, #T_b64ad_row1_col23, #T_b64ad_row1_col24, #T_b64ad_row1_col25, #T_b64ad_row1_col26, #T_b64ad_row1_col27, #T_b64ad_row1_col28, #T_b64ad_row1_col29, #T_b64ad_row1_col30, #T_b64ad_row1_col31, #T_b64ad_row1_col32, #T_b64ad_row1_col33, #T_b64ad_row1_col34, #T_b64ad_row1_col35, #T_b64ad_row1_col36, #T_b64ad_row1_col37, #T_b64ad_row1_col38, #T_b64ad_row1_col39, #T_b64ad_row1_col40, #T_b64ad_row1_col41, #T_b64ad_row1_col42, #T_b64ad_