# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the data

# %%
data=pd.read_csv('../raw_data/hr_data.csv')

# %%
data
# Out:
#           ID       Name       Department        GEO             Role  \
# 0          1     BRADDY       Operations         US               VP
# 1          2      BORST            Sales         UK  Senior Director
# 2          3   BIRDWELL          Finance     France  Senior Director
# 3          4       BENT  Human Resources      China  Senior Director
# 4          5      BAZAN               IT      Korea         Director
# ...      ...        ...              ...        ...              ...
# 14994  14995      EARLY       Operations      Korea        Level 2-4
# 14995  14996   LUNSFORD            Sales  Australia        Level 2-4
# 14996  14997  GOLDSMITH          Finance      China        Level 2-4
# 14997  14998      FLOOD  Human Resources         US        Level 2-4
# 14998  14999       Yolo               IT   Colombia        Level 2-4
#
#        Rising_Star  Will_Relocate  Critical  Trending Perf  Talent_Level  ...  \
# ...

# %% [markdown]
# # Inspecting the data

# %%
data.shape
# Out:
# (14999, 62)

# %% [markdown]
# ## Columns to drop immediately

# %% [markdown]
# ### Missing values
# * Rising_star
# * Critical
# * CSR Factor

# %% [markdown]
# ### Other Reason
# * Name

# %% [markdown]
# ### Equal values
# * Trending_Performance
# * Talent_Level
# * Validated_Talent_Level
# * EMP_Sat_OnPrem_1

# %% [markdown]
# ### Open questions
# * EMP_Sat_OnPrem_2= One indicator from a survey that was sent to employees by a third party. On prem (On premise) means that the employee maintains a high percentage of work on the corporation’s physical work locations. --> How is it different from "The percentage of the employee's work that is done remotely." and how differ the various EMP_Sat_OnPrem_3... --> Are they highly correlated? and Isn't EMP_Sat_Remote_3,... also the same but vice versa?
